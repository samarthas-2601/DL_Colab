# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthas-2601/DL_Colab/blob/main/Samartha_DL_Admission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###2. Build a Regression MLP using Sequential API considering Admission Prediction dataset

# %%
import pandas as pd
df = pd.read_csv("adission.csv")
df.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df = df.drop(['Serial No.'],axis=1)
df.head(5)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
X = df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import tensorflow 
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(3, activation="relu",input_dim = 7))
model.add(Dense(7, activation="relu"))
model.add(Dense(1, activation="linear"))

# %%
model.compile(loss="mean_squared_error", optimizer="Adam")

# %%
history = model.fit(X_train_scaled, y_train, epochs=100,  validation_split = 0.2)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 27ms/step - loss: 4.0767 - val_loss: 3.6965
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 3.3086 - val_loss: 3.0169
# Epoch 3/100
# 10/10 [==============================] - 0s 6ms/step - loss: 2.7049 - val_loss: 2.4772
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 2.2348 - val_loss: 2.0532
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.8639 - val_loss: 1.7218
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.5680 - val_loss: 1.4650
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3406 - val_loss: 1.2597
# Epoch 8/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.1574 - val_loss: 1.0966
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0081 - val_loss: 0.9653
# Epoch 10/100
# ...

# %%
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4712738111441005
